# %%
# Author: Natalia Wright
# Date Created: November 29, 2023
# Course: ITT103
'''Purpose: The Python code is a reservation system for UCC Signature Express Limited three bus classes: First, Business and
Economic. Available seats can be selected and reserved, as well as lists the total number of seats reserved for each bus.'''


# Creating arrays for each bus
FrstClass = [[0 for j in range(4)] for i in range(7)]
BusClass = [[0 for j in range(4)] for i in range(10)]
EconClass = [[0 for j in range(4)] for i in range(14)]

# Initializing variables
frstseat = int(27)
busseat = int(38)
econseat = int(56)

# User defined function for reserving seats
reservations=[]
new = None
c = None
fseat = 0
bseat = 0
eseat = 0

def reserve(T,r,c):
    global fseat, bseat, eseat
    new = (reservation_Class, row_num, col_num)
    print('\nReservation Class :', reservation_Class,'\nReserving seat: Row:', row_num ,'Column:', col_num)
    if new in reservations:
        print('Seat is occupied!')
    else:
        reservations.append(new)
        if (c == 1) or (c == 4):
            print()
        elif (c == 2) or (c == 3):
            print()
        if reservation_Class == ('First Class'):
            fseat += 1
        elif reservation_Class == ('Business Class'):
            bseat += 1
        elif reservation_Class == ('Economy'):
            eseat += 1
        print('Seat sucessfully reserved!')

# User defined function for displaying main menu
def menu():
  print('***************************************')
  print('UCC Signature Express Limited')
  print('If you want luxury travel with us')
  print('\n')
  print('1. First Class (F/f)')
  print('2. Business Class (B/b)')
  print('3. Economy Class (E/e)')
  print('4. Quit or Cancel (Q/q)')

#While loop to repeat programme
while [frstseat < float(len(FrstClass))] or [busseat < float(len(BusClass))] or [econseat < float(len(EconClass))]:

  print('\n')
  menu()
  print('\n')
  rsrv = str(input('Please select an option:'))

# First Class Bus Selection
  if rsrv in ['F', 'f']:
        reservation_Class = ('First Class')
        # Row Selection
        row_num = int(input('Enter row number '))
        if (row_num <= 7) and (row_num > 0):
            print('Row number selected!')
            print('\n')

        elif (row_num <= 0):
              print('Number must be positive or greater than zero!')
              row_num = int(input('Enter row number '))

        else:
              print('Row number must be between 1-7')
              row_num = int(input('Enter row number '))

        # Column Selection
        col_num = int(input('Enter a column number '))

        if (col_num == 1) or (col_num == 4):
              print('Window seat selected!')
              reserve(reservation_Class,row_num,col_num)
              FrstClass.append(1)

        elif (col_num == 2) or (col_num == 3):
              print('Aisle seat selected!')
              reserve(reservation_Class,row_num,col_num)
              FrstClass.append(1)

        elif (col_num <= 0):
              print('Number must be positive or greater than zero')
              col_num = int(input('Enter a column number '))
              reserve(reservation_Class,row_num,col_num)
              FrstClass.append(1)

        else:
              print('Column number must be between 1-4')
              col_num = int(input('Enter a column number '))
              reserve(reservation_Class,row_num,col_num)
              FrstClass.append(1)

# Business Class Bus Selection
  elif rsrv in ['B', 'b']:
        reservation_Class = ('Business Class')
        # Row Selection
        row_num = int(input('Enter row number '))
        if (row_num <= 10) and (row_num > 0):
              print('Row number selected!')
              print('\n')

        elif (row_num <= 0):
             print('Number must be positive or greater than zero!')
             row_num = int(input('Enter row number '))

        else:
            print('Row number must be between 1-10')
            row_num = int(input('Enter row number '))

        # Column Selection
        col_num = int(input('Enter a column number '))

        if (col_num == 1) or (col_num == 4):
            print('Window seat selected!')
            reserve(reservation_Class,row_num,col_num)
            BusClass.append(1)

        elif (col_num == 2) or (col_num == 3):
            print('Aisle seat selected!')
            reserve(reservation_Class,row_num,col_num)
            BusClass.append(1)

        elif (col_num <= 0):
            print('Number must be positive or greater than zero')
            col_num = int(input('Enter a column number '))
            reserve(reservation_Class,row_num,col_num)
            BusClass.append(1)

        else:
            print('Column number must be between 1-4')
            col_num = int(input('Enter a column number '))
            reserve(reservation_Class,row_num,col_num)
            BusClass.append(1)

# Economic Class Bus Selection
  elif rsrv in ['E','e']:
        reservation_Class = ('Economy')
        # Row Selection
        row_num = int(input('Enter row number '))
        if (row_num <= 14) and (row_num > 0):
            print('Row number selected!')
            print('\n')

        elif (row_num <= 0):
            print('Number must be positive or greater than zero!')
            row_num = int(input('Enter row number '))

        else:
            print('Row number must be between 1-14')
            row_num = int(input('Enter row number '))

        # Column Selection
        col_num = int(input('Enter a column number '))

        if (col_num == 1) or (col_num == 4):
            print('Window seat selected!')
            reserve(reservation_Class,row_num,col_num)
            EconClass.append(1)

        elif (col_num == 2) or (col_num == 3):
            print('Aisle seat selected!')
            reserve(reservation_Class,row_num,col_num)
            EconClass.append(1)

        elif (col_num <= 0):
            print('Number must be positive or greater than zero')
            col_num = int(input('Enter a column number '))
            reserve(reservation_Class,row_num,col_num)
            EconClass.append(1)

        else:
            print('Column number must be between 1-4')
            col_num = int(input('Enter a column number '))
            reserve(reservation_Class,row_num,col_num)
            EconClass.append(1)

# Quit or Cancel Selection
  elif rsrv in ['Q', 'q']:
            print('First Class')
            print('Total number of first class seats:', frstseat)

#Calculation of seats reserved
            frsrv = int(len(FrstClass))
            if frsrv == 0:
                    print('No more available seats!')
            else:
                    print('Number of seats reserved:', frsrv)

            print('\n')
            print('Business Class')
            print('Total number of business class seats:', busseat)

#Calculation of seats reserved
            brsrv = int(len(BusClass))
            if brsrv == 0:
                    print('No more available seats!')
            else:
                    print('Number of seats reserved:', brsrv)

            print('\n')
            print('Economic Class')
            print('Total number if economy class seats:', econseat)

#Calculation of seats reserved
            ersrv = int(len(EconClass))
            if ersrv == 0:
                print('No more available seats!')
            else:
                print('Number of seats reserved:', ersrv)

  else:
    print('Invalid Choice!')
